# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Plotando dados categóricos

# %%
sns.catplot(x='sex',kind='count',palette='Set2',data=tips)

# %%
sns.catplot(y='day',kind='count',palette='Set1',data=tips)

# %%
sns.catplot(y='day',x='total_bill',palette='Set2',data=tips)

# %% [markdown]
# O parâmetro swarm evita sobreposição de pontos

# %% [markdown]
# Usar somente para poucos pontos

# %%
sns.catplot(x='day',y='total_bill',kind='swarm',data=tips)

# %%
sns.catplot(x='day',y='total_bill',kind='swarm',hue='sex',palette='Dark2',data=tips)

# %%
sns.catplot(x='day',y='total_bill',kind='swarm',hue='sex',order=['Sat','Sun','Fri','Thur'],data=tips)

# %% [markdown]
# Invertendo a visualização para plots horizontais

# %%
sns.catplot(x='total_bill',y='day',kind='swarm',data=tips)

# %% [markdown]
# Gráficos com regressão

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
# %matplotlib inline
sns.lmplot(x='total_bill',y='tip',hue='sex',palette='Pastel1',data=tips)

# %% [markdown]
# Separando os gráficos pela coluna Time

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',col='time',palette='Set2',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',col='time',palette='Set2',data=tips)

# %% [markdown]
# Parâmetros scatter_kws e line_kws

# %% [markdown]
# Configura os pontos e as linhas

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',col='time',palette='Set1',data=tips,scatter_kws={'s': 90, 'alpha': 0.5},
          line_kws={'lw': 4})

# %% [markdown]
# Segregando gráficos pelo parâmetro col e pelo parâmetro row

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',col='time',row='sex',palette='Set2',data=tips)

# %% [markdown]
# Visualizando a distribuição de observações

# %% [markdown]
# Muito útil para visualizar outliers

# %%
#Boxplot de dias da semana por total de conta
sns.catplot(x='day',y='total_bill',kind='box',data=tips)

# %%
#Boxplot dos dias por total de conta e se a pessoa é fumante ou não
sns.catplot(x='day',y='total_bill',hue='smoker',kind='box',data=tips)

# %%
#Tipo de boxplot com foco maior na forma dos dados do que nos outliers
#Tipo de gráfico interessante quando temos grandes datasets
#Não dá informações sobre outliers
sns.catplot(x='day',y='total_bill',kind='boxen',data=tips)

# %%
#O método stripplot permite plotar a distribuição dos dados
sns.catplot(x='day',y='total_bill',kind='boxen',data=tips)
sns.stripplot(x='day',y='total_bill',data=tips,color='gray')

# %%
#Método catplot usando facetgrid para combinar gráficos em uma única figura
sns.catplot(x='sex',y='total_bill',hue='smoker',col='time',data=tips,kind='boxen',height=4)

# %% [markdown]
# Violin plots
# Ideal para visualizar distribuição de variáveis
# Funciona bem para distribuições com picos
# Permite uma visualização mais rica do que com o Boxplot normal

# %%
sns.catplot(x='day',y='total_bill',kind='violin',data=tips)

# %%
#Horizontal
sns.catplot(y='day',x='total_bill',kind='violin',data=tips)

# %%
#Usando o parâmetro Hue para ter uma terceira variável
sns.catplot(x='day',y='total_bill',hue='time',kind='violin',data=tips)

# %%
#Dividindo o violinplot com o parâmetro split 
#Útil quando temos muitos dados para exibir
sns.catplot(x='day',y='total_bill',hue='sex',split=True,kind='violin',data=tips)

# %%
#Usando o parâmetro inner para preencher o violin plot com observações
#Útil para destacar bem as partes que possuem mais dados
sns.catplot(x='day',y='total_bill',hue='sex',split=True,inner='stick',palette='pastel',kind='violin',data=tips)

# %%
#Utilizando o swarm com o violinplot
#Fica mais explícito ainda a frequência de pontos nas partes do violino
sns.catplot(x='day',y='total_bill',hue='sex',split=True,palette='pastel',kind='violin',data=tips)
sns.swarmplot(x='day',y='total_bill',color='k',size=3,data=tips)

# %%
sns.catplot(x='day',y='total_bill',palette='pastel',kind='violin',data=tips)
sns.swarmplot(x='day',y='total_bill',color='k',size=3,data=tips)

# %% [markdown]
# <b>Visualizando a distribuição de um Dataset</b>
# <br>
# Histograma - tenta encontrar a melhor quantidade de bins

# %%
sns.set(color_codes=True)
sns.distplot(tips.total_bill,kde=False)

# %%
#Plotando um histograma para uma distribuição normal
import numpy as np
x = np.random.normal(size=100)

# %%
x
# Out:
# array([ 0.49775611,  0.09466538,  0.30066298, -1.10154422, -1.36231326,
#        -0.09402443,  1.00642626, -0.37328742, -0.20932255,  0.1739239 ,
#         1.24026077, -0.58200565, -0.34719129, -0.05711693,  0.52871621,
#         0.47596964, -0.34954161, -1.35130353,  0.13283884,  0.05101113,
#         0.40365985, -0.84852557, -0.7261504 ,  1.05593849, -0.88946725,
#         3.05127868, -0.40676623, -0.1226352 ,  2.09191681,  0.58487672,
#         0.65389902,  0.99566092, -0.19031283,  0.01157792,  0.46623602,
#        -1.54485769,  0.23319153, -0.60769681, -0.40603254, -0.01429593,
#        -0.42047728, -0.61103931,  0.53323393, -2.15258902,  0.80487391,
#        -1.97806849,  0.64868979,  0.45815649,  2.28555135,  0.01197844,
#         0.63360832,  0.73599863,  3.22330707,  0.5115327 , -0.57350542,
#         0.47300599, -0.88304482,  0.38478754,  0.85114349, -1.85391679,
#         0.08796787, -0.81032927,  0.87501589,  1.35170215, -0.6887052 ,
#         0.06617743, -0.37848818, -0.64347452,  0.49361244,  1.44080927,
#        -0.86370633, -0.01688554,  0.58251957,  0.63108685,  1.89990791,
#         0.26109666,  0.04883576,  0.3673316 , -0.70473941,  0.06406196,
#        -0.44431053,  1.90890785,  1.1561932 ,  0.71692104, -0.97175692,
#         0.42167735,  0.78505884,  0.7064788 , -1.14989215, -0.56431686,
#        -0.67614774,  0.42556177,  0.54977284,  0.84561147,  1.03353046,
#         0.32907337, -0.97017198, -1.13516415,  1.41950263,  0.93112318])

# %%
sns.distplot(x)

# %%
#Kde = curva da distribuição
sns.distplot(tips.total_bill,bins=20,kde=True)

# %%
sns.distplot(tips.total_bill,bins=10,kde=True)

# %%
#Visualizando apenas o KDE
sns.distplot(tips.total_bill,hist=False)

# %% [markdown]
# <b>Parâmetro rug</b>

# %%
#Mostra a aglomeração dos dados
sns.distplot(tips.total_bill,hist=False,rug=True)

# %%
sns.distplot(tips.total_bill,hist=True,rug=True)

# %% [markdown]
# <b>Jointplot (scatterplot e histograma)</b>

# %%
#Quando queremos ver a distribuição de duas variáveis
sns.jointplot(x='tip',y='total_bill',color='r',data=tips)

# %% [markdown]
# <b>Hexbin plots</b>

# %%
#Adequando para visualização de grandes conjuntos de dados
#Tende a funcionar melhor com as cores em branco de fundo
sns.jointplot(x='tip',y='total_bill',color='b',kind='hex',data=tips)

# %%
#Usando o kde para plotar mais de uma variável
#Kernel com a densidade dos dados
sns.jointplot(x='tip',y='total_bill',color='b',kind='kde',data=tips)

# %% [markdown]
# <b>Visualizando relacionamentos emparelhados</b>
# <br>
# Plota múltiplas variáveis de um dataset<br>
# Cria uma matriz de eixos para mostrar a relação de cada par de coluns no dataframe<br>
# Por padrão plota também um histograma de cada coluna no dataframe na diagonal da matriz

# %%
sns.pairplot(tips)

# %%
#Carregando o dataset iris
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Plot pares emparelhados segregando pela coluna species
sns.pairplot(iris,hue='species',palette='Set1')

# %%
#Plotando scatter plots com regressão
sns.pairplot(iris,kind='reg')

# %%
#Forçando a geração do histograma na diagonal
sns.pairplot(iris,hue='species',diag_kind='hist')

# %%
#Plotando apenas duas colunas do dataframe
sns.pairplot(iris,hue='species',vars=['sepal_width','sepal_length'],palette='husl')

# %% [markdown]
# <b>Gráficos de correlação</b>
# Útils para visualizar se existem correlações positivas ou negativas entre colunas<br>
# Método corr() do pandas possibilita calcular correlação por tipo spearman ou pearson

# %%
correlacoes = tips.corr()

# %%
correlacoes
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
ax = sns.heatmap(correlacoes)

# %%
#Exibe os valores de correlação
ax = sns.heatmap(correlacoes,annot=True)

# %%
correlacoes = iris.corr()

# %%
correlacoes
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
ax = sns.heatmap(correlacoes,cmap='PuOr',annot=True)

# %% [markdown]
# <b>Acessar a galeria de gráficos da seabon no site deles</b>
